# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, StratifiedKFold
import catboost as ct
# %matplotlib inline

import lightgbm as lgb
# Out:
# /root/anaconda3/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.4 of module '_catboost' does not match runtime version 3.5
#   return f(*args, **kwds)

# %%
train = pd.read_csv('data/train_set_weeks.csv')
test = pd.read_csv('data/test_set_weeks.csv')
#val_idx = train['N wk'] >= 173
#X_val = train[val_idx]
X_train = train#[~val_idx]
X_test = test

# %%
X_train.groupby(['idFilial', 'KanalDB', 'idSubGrp'])[['value']].mean()

# %%
X_train_cumsum = pd.DataFrame()
X_train_cumsum.columns = ['value_cumsum']

# %%
y_train = X_train['value'].values
y_val = X_val['value'].values

X_train.drop('value', inplace=True, axis=1)
X_val.drop('value', inplace=True, axis=1)

X_train.drop(['id', 'wk'], inplace=True, axis=1)
X_val.drop(['id', 'wk'], inplace=True, axis=1)
X_test.drop(['id', 'wk'], inplace=True, axis=1)

# %%
dtrain = ct.Pool(X_train, label=y_train, cat_features=[1, 2, 3])
#dval = ct.Pool(X_val, label=y_val, cat_features=[0, 1, 2])

# %%
clf = ct.CatBoostRegressor(random_seed=0, eval_metric='RMSE', logging_level='Silent')

# %%
clf.fit(dtrain)

# %%
dtest = ct.Pool(X_test, cat_features=[1, 2, 3])
y_pred = clf.predict(dtest)

# %%
y_sample = pd.read_csv('data/sample_submission.csv')

# %%
y_pred
# Out:
# array([ 127641.08237216,  127641.08237216,  127641.08237216, ...,
#          11104.49348116,   11104.49348116,   11104.49348116])

# %%
y_sample['value'] = y_pred

# %%
y_sample.to_csv('very_noobski_submit.csv', index=False)

# %%
train
# Out:
#           id      wk  N wk  idFilial  KanalDB  idSubGrp     value
# 0          0  201401     1         9        2         3    3560.0
# 1          1  201402     2         9        2         3    7120.0
# 2          2  201403     3         9        2         3   57672.0
# 3          3  201404     4         9        2         3   37380.0
# 4          4  201405     5         9        2         3   80990.0
# 5          5  201406     6         9        2         3   -8900.0
# 6          6  201407     7         9        2         3  131364.0
# 7          7  201408     8         9        2         3   67818.0
# 8          8  201409     9         9        2         3   80100.0
# 9          9  201410    10         9        2         3    8544.0
# 10        10  201411    11         9        2         3   56604.0
# 11        11  201412    12         9        2         3  105020.0
# 12        12  201413    13         9        2         3  110894.0
# ...

# %%
test
# Out:
#         id      wk  N wk  idFilial  KanalDB  idSubGrp
# 0        0  201729   184         9        2         3
# 1        1  201730   185         9        2         3
# 2        2  201731   186         9        2         3
# 3        3  201732   187         9        2         3
# 4        4  201733   188         9        2         3
# 5        5  201734   189         9        2         3
# 6        6  201735   190         9        2         3
# 7        7  201736   191         9        2         3
# 8        8  201737   192         9        2         3
# 9        9  201738   193         9        2         3
# 10      10  201739   194         9        2         3
# 11      11  201729   184         9        2         4
# 12      12  201730   185         9        2         4
# 13      13  201731   186         9        2         4
# 14      14  201732   187         9        2         4
# 15      15  201733   188         9        2         4
# ...
